# %% [markdown]
# # Random Forest Classifier

# %% [markdown]
# # Importing essential libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns  
import warnings
import pickle
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.utils import shuffle
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# # Reading the Dataset

# %%
diabetes = pd.read_csv("OriginalDataset.csv")

# %%
diabetes
# Out:
#       age  sex  residence  Systollic Blood Pressure  Distollic Blood Pressure  \
# 0      13    0          1                     143.0                     108.0
# 1      14    1          1                       NaN                       NaN
# 2      14    1          1                     125.0                      83.0
# 3      15    1          1                     101.0                      58.0
# 4      15    0          1                     121.0                      80.0
# 5      15    1          1                     103.0                      64.0
# 6      15    0          1                     134.0                      91.0
# 7      17    0          1                     107.0                      61.0
# 8      17    0          0                      90.0                      61.0
# 9      17    1          1                     107.0                      76.0
# 10     17    1          1                     139.0                      81.0
# 11     17    0          1                     109.0                      72.0
# 12     18    1          0                     128.0                      98.0
# 13     18    1          0                       NaN                       NaN
# 14     18    0          1                     100.0                      54.0
# 15     18    0          1                     123.0                      61.0
# 16     18    0          1                     121.0                      88.0
# 17     18    0          1                     105.0                      81.0
# 18     18    1          1                     115.0                      80.0
# 19     19    0          1                     154.0                      80.0
# 20     19    0          1                      97.0                      67.0
# 21     20    1          1                       NaN                       NaN
# 22     20    0          1                     131.0                      70.0
# 23     20    0          1                     113.0                      82.0
# 24     20    0          1                     102.0                      71.0
# 25     20    0          1                     134.0                      93.0
# 26     20    0          1                     139.0                      73.0
# 27     21    0          0                     117.0                      73.0
# 28     21    0          1                     149.0                      86.0
# 29     21    0          1                     114.0                      76.0
# ...   ...  ...        ...                       ...                       ...
# 2469   60    1          0                     130.0                      80.0
# 2470   60    1          0                     151.0                      67.0
# 2471   60    1          0                     138.0                      70.0
# 2472   60    0          0                     120.0                      80.0
# 2473   60    0          0                     164.0                      84.0
# 2474   60    1          0                     160.0                     100.0
# 2475   60    1          0                     130.0                      80.0
# 2476   60    1          0                     130.0                      80.0
# 2477   60    0          0                     168.0                     107.0
# 2478   60    1          0                     123.0                      78.0
# 2479   60    0          0                     130.0                      78.0
# 2480   60    0          0                     130.0                      78.0
# 2481   60    0          0                     125.0                      78.0
# 2482   60    1          1                     106.0                      72.0
# 2483   60    0          0                     125.0                      78.0
# 2484   60    1          0                     136.0                      69.0
# 2485   60    0          0                     135.0                      70.0
# 2486   60    1          1                     141.0                      90.0
# 2487   60    0          0                     135.0                      70.0
# 2488   60    0          1                     138.0                      92.0
# 2489   60    0          0                     122.0                      64.0
# 2490   60    0          1                     131.0                      84.0
# 2491   60    1          0                     139.0                      75.0
# 2492   60    1          0                     121.0                      83.0
# 2493   60    1          0                     163.0                      79.0
# 2494   60    1          0                     140.0                      72.0
# 2495   60    1          0                     108.0                      68.0
# 24        High-Risk
# 25        High-Risk
# 26        High-Risk
# 27         Low-Risk
# 28        High-Risk
# 29        High-Risk
# ...              ...
# 2469       Low-Risk
# 2470       Low-Risk
# 2471       Low-Risk
# 2472       Low-Risk
# 2473       Low-Risk
# 2474       Low-Risk
# 2475       Low-Risk
# 2476       Low-Risk
# 2477       Low-Risk
# 2478       Low-Risk
# 2479       Low-Risk
# 2480       Low-Risk
# 2481       Low-Risk
# 2482       Low-Risk
# 2483       Low-Risk
# 2484       Low-Risk
# 2485       Low-Risk
# 2486       Low-Risk
# 2487       Low-Risk
# 2488       Low-Risk
# 2489       Low-Risk
# 2490       Low-Risk
# 2491       Low-Risk
# 2492       Low-Risk
# 2493       Low-Risk
# 2494       Low-Risk
# 2495      High-Risk
# 2496      High-Risk
# 2497      High-Risk
# 2498      High-Risk
#
# [2499 rows x 14 columns]

# %% [markdown]
# # Shuffle the data to avoid biasness

# %%
diabetes = shuffle(diabetes,random_state = 22)

# %% [markdown]
# # Filling the null values with the forward fill (ffill)

# %%
diabetes = pd.DataFrame(diabetes).fillna(method='ffill')

# %% [markdown]
# # Importing a preprocessing module

# %%
from sklearn.preprocessing import LabelEncoder

# Convert target label to numerical Data
le = LabelEncoder()
diabetes['diabetes status'] = le.fit_transform(diabetes['diabetes status'])
#diabetes['occupation'] = le.fit_transform(diabetes['occupation'])

# %% [markdown]
# # Separate training features from target

# %%
from sklearn.model_selection import train_test_split
X = diabetes.drop(columns=['diabetes status','occupation'])
y = diabetes['diabetes status']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=7)

# %% [markdown]
# # Model Selection

# %%
# Creating Random Forest Model
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators=20)
classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=20,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
classifier.fit(X_test,y_test)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=20,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
# Import GridSearchCV
from sklearn.model_selection import GridSearchCV

# Optimize model paramaters 

#Set your parameter grid here
param_grid = {}
grid_model = GridSearchCV(classifier, param_grid)
grid_model.fit(X_train, y_train)
grid_model.fit(X_test,y_test)
print(grid_model.best_params_)
# Out:
# {}

# %%
# import evaluation metrics 
from sklearn.metrics import confusion_matrix, accuracy_score

#evaluate the model
y_pred = classifier.predict(X_test)

# Get error rate
print("Error rate of Random Forest classifier: ", 1 - accuracy_score(y_test, y_pred))

# Get confusion matrix
confusion_matrix(y_pred, y_test)
# Out:
# Error rate of Random Forest classifier:  0.002666666666666706
# array([[150,   1],
#        [  1, 598]], dtype=int64)

# %%
accuracy = accuracy_score(y_pred, y_test) * 100
print('Accuracy: %f' % accuracy)
# Out:
# Accuracy: 99.733333

# %% [markdown]
# # Creating a pickle file for the classifier

# %%
# Creating a pickle file for the classifier
filename = 'diabetes-prediction-rfc-model.pkl'
pickle.dump(classifier, open(filename, 'wb'))
